# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from PIL import Image

# %%
img = Image.open('Interstellar Film.jfif')

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=736x1413>

# %%
type(img)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
img_arr=np.asarray(img)
img_arr
# Out:
# array([[[  0,   1,   5],
#         [  0,   1,   5],
#         [  0,   1,   5],
#         ...,
#         [  0,   0,   9],
#         [  0,   0,   9],
#         [  0,   0,   9]],
#
#        [[ 48,  57,  62],
#         [ 48,  57,  62],
#         [ 49,  58,  63],
#         ...,
#         [ 31,  35,  44],
#         [ 31,  35,  44],
#         [ 31,  35,  44]],
#
#        [[121, 139, 143],
#         [121, 139, 143],
#         [121, 139, 143],
#         ...,
#         [ 87,  97, 106],
#         [ 87,  97, 106],
#         [ 87,  97, 106]],
#
#        ...,
#
#        [[ 28,  36,  47],
#         [ 30,  38,  49],
#         [ 30,  38,  49],
#         ...,
#         [ 33,  42,  49],
#         [ 22,  31,  38],
#         [ 20,  29,  36]],
#
#        [[ 19,  27,  38],
#         [ 14,  22,  33],
#         [ 10,  18,  29],
#         ...,
#         [ 30,  39,  46],
#         [ 27,  36,  43],
#         [ 31,  40,  47]],
#
#        [[ 11,  21,  31],
#         [ 19,  29,  39],
#         [ 25,  35,  45],
# ...

# %%
plt.imshow(img_arr)

# %%
Ai=img_arr.copy()
Ai
# Out:
# array([[[  0,   1,   5],
#         [  0,   1,   5],
#         [  0,   1,   5],
#         ...,
#         [  0,   0,   9],
#         [  0,   0,   9],
#         [  0,   0,   9]],
#
#        [[ 48,  57,  62],
#         [ 48,  57,  62],
#         [ 49,  58,  63],
#         ...,
#         [ 31,  35,  44],
#         [ 31,  35,  44],
#         [ 31,  35,  44]],
#
#        [[121, 139, 143],
#         [121, 139, 143],
#         [121, 139, 143],
#         ...,
#         [ 87,  97, 106],
#         [ 87,  97, 106],
#         [ 87,  97, 106]],
#
#        ...,
#
#        [[ 28,  36,  47],
#         [ 30,  38,  49],
#         [ 30,  38,  49],
#         ...,
#         [ 33,  42,  49],
#         [ 22,  31,  38],
#         [ 20,  29,  36]],
#
#        [[ 19,  27,  38],
#         [ 14,  22,  33],
#         [ 10,  18,  29],
#         ...,
#         [ 30,  39,  46],
#         [ 27,  36,  43],
#         [ 31,  40,  47]],
#
#        [[ 11,  21,  31],
#         [ 19,  29,  39],
#         [ 25,  35,  45],
# ...

# %%
Ai.shape
# Out:
# (1413, 736, 3)

# %%
plt.imshow(Ai[:,:,0])

# %%
Ai[:,:,0]
# Out:
# array([[  0,   0,   0, ...,   0,   0,   0],
#        [ 48,  48,  49, ...,  31,  31,  31],
#        [121, 121, 121, ...,  87,  87,  87],
#        ...,
#        [ 28,  30,  30, ...,  33,  22,  20],
#        [ 19,  14,  10, ...,  30,  27,  31],
#        [ 11,  19,  25, ...,  11,  15,  23]], dtype=uint8)

# %%
plt.imshow(Ai[:,:,0], cmap='gray')

# %%
plt.imshow(Ai[:,:,0], cmap='Blues')

# %%
plt.imshow(Ai[:,:,0], cmap='Reds')

# %%
plt.imshow(Ai[:,:,0], cmap='PuBu')

# %%
plt.imshow(Ai[:,:,0], cmap='Purples')
