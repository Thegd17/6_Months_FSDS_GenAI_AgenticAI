# %%
word = "Gaurav"
# Out:
# ['G', 'a', 'u', 'r', 'a', 'v']

# %%
def encoder(word):
    chars = 
    return chars
# Out:
#   Cell In[11], line 2
#     chars = [for i in word as i]
#              ^
# SyntaxError: invalid syntax

# %%
encoder(word)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 encoder(word)
#
# Cell In[9], line 2, in encoder(word)
#       1 def encoder(word):
# ----> 2     chars = word.slpit()
#       3     return chars
#
# AttributeError: 'str' object has no attribute 'slpit'
